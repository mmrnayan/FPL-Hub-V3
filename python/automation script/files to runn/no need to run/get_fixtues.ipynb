# %%
import requests
import pandas as pd

resp = requests.get("https://fantasy.premierleague.com/api/fixtures/")
fixtures_raw = resp.json()
season = 2627
df = pd.DataFrame(fixtures_raw, dtype=str)
df['season'] = season
df.to_csv(rf"C:\Users\JesseOnu\fpl sql rework\fixtures\{season}fixtures.csv", index=False)

# %%
df.head(2)
# Out:
#       code event finished finished_provisional id          kickoff_time  \
# 0  2645195     1     True                 True  1  2026-08-21T19:00:00Z
# 1  2645198     1     True                 True  4  2026-08-22T11:30:00Z
#
#   minutes provisional_start_time started team_a team_a_score team_h  \
# 0      90                  False    True      7          0.0      1
# 1      90                  False    True     16          0.0     11
#
#   team_h_score                                              stats  \
# 0          3.0  [{'identifier': 'goals_scored', 'a': [], 'h': ...
# 1          2.0  [{'identifier': 'goals_scored', 'a': [], 'h': ...
#
#   team_h_difficulty team_a_difficulty pulse_id  season
# 0                 2                 5        0    2627
# 1                 4                 2        0    2627

# %%
df['stats'][1]
# Out:
# "[{'identifier': 'goals_scored', 'a': [], 'h': [{'value': 1, 'element': 279}, {'value': 1, 'element': 586}]}, {'identifier': 'assists', 'a': [], 'h': [{'value': 1, 'element': 290}, {'value': 1, 'element': 295}]}, {'identifier': 'own_goals', 'a': [], 'h': []}, {'identifier': 'penalties_saved', 'a': [], 'h': []}, {'identifier': 'penalties_missed', 'a': [], 'h': []}, {'identifier': 'yellow_cards', 'a': [{'value': 1, 'element': 415}], 'h': [{'value': 1, 'element': 287}, {'value': 1, 'element': 289}]}, {'identifier': 'red_cards', 'a': [], 'h': []}, {'identifier': 'saves', 'a': [{'value': 2, 'element': 412}], 'h': [{'value': 5, 'element': 572}]}, {'identifier': 'bonus', 'a': [], 'h': [{'value': 3, 'element': 572}, {'value': 2, 'element': 279}, {'value': 1, 'element': 586}]}, {'identifier': 'bps', 'a': [{'value': 18, 'element': 426}, {'value': 17, 'element': 162}, {'value': 15, 'element': 418}, {'value': 14, 'element': 428}, {'value': 13, 'element': 43}, {'value': 13, 'element': 423}, {'value': 12, 'element': 427}, {'value': 9, 'element': 429}, {'value': 8, 'element': 422}, {'value': 7, 'element': 412}, {'value': 7, 'element': 432}, {'value': 6, 'element': 417}, {'value': 5, 'element': 421}, {'value': 3, 'element': 435}, {'value': 2, 'element': 439}, {'value': -11, 'element': 415}], 'h': [{'value': 41, 'element': 572}, {'value': 39, 'element': 279}, {'value': 35, 'element': 586}, {'value': 27, 'element': 277}, {'value': 24, 'element': 282}, {'value': 23, 'element': 280}, {'value': 21, 'element': 295}, {'value': 20, 'element': 290}, {'value': 11, 'element': 576}, {'value': 9, 'element': 289}, {'value': 8, 'element': 286}, {'value': 4, 'element': 281}, {'value': 4, 'element': 585}, {'value': 3, 'element': 285}, {'value': 3, 'element': 556}, {'value': 2, 'element': 287}]}, {'identifier': 'defensive_contribution', 'a': [{'value': 9, 'element': 162}, {'value': 6, 'element': 426}, {'value': 5, 'element': 43}, {'value': 5, 'element': 422}, {'value': 4, 'element': 418}, {'value': 4, 'element': 423}, {'value': 4, 'element': 427}, {'value': 3, 'element': 417}, {'value': 3, 'element': 428}, {'value': 2, 'element': 421}, {'value': 1, 'element': 415}, {'value': 1, 'element': 429}, {'value': 1, 'element': 432}, {'value': 1, 'element': 435}], 'h': [{'value': 21, 'element': 277}, {'value': 13, 'element': 586}, {'value': 10, 'element': 286}, {'value': 9, 'element': 289}, {'value': 7, 'element': 279}, {'value': 6, 'element': 282}, {'value': 6, 'element': 576}, {'value': 5, 'element': 295}, {'value': 4, 'element': 585}, {'value': 3, 'element': 281}, {'value': 3, 'element': 287}, {'value': 3, 'element': 290}, {'value': 2, 'element': 280}, {'value': 2, 'element': 285}]}]"
